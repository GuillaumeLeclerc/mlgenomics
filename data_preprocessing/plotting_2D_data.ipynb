# %% [markdown]
# #### plotting the 2D data generated with processing_2d.py script

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
data = np.load('/Users/work/Documents/GitHub/mlgenomics/data_preprocessing/Wang_2018_all_2D_processed_new.npy', allow_pickle=True)

# %%
def plot_annotations(data, exclude,start,end):
    new_data = []
    new_labels = []
    for i in range(len(dirs)):
        data_dir = os.path.join('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/combinatorially_encoded/all_datasets',dirs[i],'class_labels.csv')
        labels = pd.read_csv(data_dir)
        if labels.shape[0] < data[i].shape[0]:
            new_data.append(data[i][range(labels.shape[0]),start:end])
            labels = labels['ClusterName'].to_list()
            new_labels.append([None if item in exclude else item for item in labels])
        else:
            new_data.append(data[i][:,start:end])
            labels = labels.loc[range(data[i].shape[0]),:]
            labels = labels['ClusterName'].to_list()
            labels = [None if item in exclude else item for item in labels]
            new_labels.append(labels)


    all_labels = np.concatenate(new_labels)
    all_newdata = pd.DataFrame(np.concatenate(new_data))

    all_d = pd.concat([all_newdata, pd.DataFrame(all_labels)],axis=1)
    all_d.columns = ['x', 'y','z','dataset','label']
    all_d.head()

    g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = 'label',palette= sns.color_palette("bright", 11), sharex=False, sharey=False)
    g.map(plt.scatter, 'x', 'y', s=5, lw=1)
    g.add_legend()

    return g, labels


def plot_genes(data,index,genename, cmap):
    
  
    all_newdata = pd.DataFrame(data)
    all_d = pd.concat([all_newdata.loc[:,list(range(1030,1034))], pd.DataFrame(all_newdata.loc[:,index])], axis = 1)
    all_d.columns = ['x', 'y','z','dataset',genename ]
    vmin = np.min(all_d[genename])
    vmax = np.max(all_d[genename])
    
    g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = genename,palette= cmap, sharex=False, sharey=False)
    g.map(plt.scatter, 'x', 'y', s=5, lw=1, vmin = vmin, vmax = vmax)
    
    # Make space for the colorbar
    g.fig.subplots_adjust(right=.92)

    # Define a new Axes where the colorbar will go
    cax = g.fig.add_axes([.94, .25, .02, .6])

    # Get a mappable object with the same colormap as the data
    points = plt.scatter([], [], c=[], vmin=vmin, vmax=vmax, cmap=cmap)

    # Draw the colorbar
    g.fig.colorbar(points, cax=cax)

    return g

# function from here: https://github.com/weallen/STARmap/blob/master/python/analysis.py
def load_data(data_dir, prefix="Cell"):
        #expr = pd.read_csv(os.path.join(data_dir, "data_table.csv"), index_col=0)
    expr = pd.read_csv(os.path.join(data_dir, "cell_barcode_count.csv"), header=None)
    gene_names = pd.read_csv(os.path.join(data_dir, "cell_barcode_names.csv"),header=None)
    rownames = [i for i in range(expr.shape[0])]
    names = gene_names[2]
    names.name = "Gene"
    return pd.DataFrame(data=expr.values, columns=names, index=rownames)

# %%
#  get union of all gene names (across 3D and 2D datasets)
genenames_3D = pd.read_csv('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/sequentially_encoded_Wang_et_al_2018/gene_names.csv', header = 0)

dirs = os.listdir('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/combinatorially_encoded/all_datasets')

ct = []

for i in range(len(dirs)):

    data_dir1 = os.path.join('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/combinatorially_encoded/all_datasets',dirs[i])

    ct.append(load_data(data_dir1, prefix=""))

genenames = []
for i in range(len(dirs)):
    genenames.append(ct[i].columns)

all_genes = np.unique(np.concatenate((np.unique(np.concatenate(genenames)),(np.array(genenames_3D).flatten()))))

# %%
np.save('2d_genes.npy',all_genes)

# %%
out = np.load('/Users/work/Documents/GitHub/mlgenomics/datasets/Wang_2018_all_2D_3D_processed.npz')['arr_0']

out[out[:,-1]==0,:].shape
# Out:
# (11578, 1034)

# %%
np.unique(out[:,-1])
# Out:
# array([ 0., 33.])

# %%
dd = out[out[:,-1]==0,:]
all_newdata = pd.DataFrame(dd)
all_d = pd.concat([all_newdata.loc[:,list(range(1030,1034))], pd.DataFrame(all_newdata.loc[:,np.array(np.argwhere(all_genes=='Cux2')).flatten()])], axis = 1)
    
all_d.columns = ['x', 'y','z','dataset','genename' ]
vmin = np.min(all_d['genename'])
vmax = np.max(all_d['genename'])

g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = 'genename',palette= 'Blues', sharex=False, sharey=False)
g.map(plt.scatter, 'x', 'y', s=5, lw=1, vmin = vmin, vmax = vmax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/legend.py in get_legend_handler(legend_handler_map, orig_handle)
#     756         try:
# --> 757             return legend_handler_map[orig_handle]
#     758         except (TypeError, KeyError):  # TypeError if unhashable.
#
# KeyError: <matplotlib.collections.PathCollection object at 0x138297860>
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-76c1e2733504> in <module>
#       8
#       9 g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = 'genename',palette= 'Blues', sharex=False, sharey=False)
# ---> 10 g.map(plt.scatter, 'x', 'y', s=5, lw=1, vmin = vmin, vmax = vmax)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     839
#     840         # Sort out the supporting information
# --> 841         self._update_legend_data(ax)
#     842         self._clean_axis(ax)
#     843
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in _update_legend_data(self, ax)
#     130     def _update_legend_data(self, ax):
#     131         """Extract the legend data from an axes object and save it."""
# --> 132         handles, labels = ax.get_legend_handles_labels()
#     133         data = {l: h for h, l in zip(handles, labels)}
#     134         self._legend_data.update(data)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in get_legend_handles_labels(self, legend_handler_map)
#     294         # pass through to legend.
#     295         handles, labels = mlegend._get_legend_handles_labels([self],
# --> 296                 legend_handler_map)
#     297         return handles, labels
#     298
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/legend.py in _get_legend_handles_labels(axs, legend_handler_map)
#    1240     labels = []
#    1241
# -> 1242     for handle in _get_legend_handles(axs, legend_handler_map):
#    1243         label = handle.get_label()
#    1244         if label and not label.startswith('_'):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/legend.py in _get_legend_handles(axs, legend_handler_map)
#    1228     for handle in handles_original:
#    1229         label = handle.get_label()
# -> 1230         if label != '_nolegend_' and has_handler(handler_map, handle):
#    1231             yield handle
#    1232
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/legend.py in get_legend_handler(legend_handler_map, orig_handle)
#     755         """
#     756         try:
# --> 757             return legend_handler_map[orig_handle]
#     758         except (TypeError, KeyError):  # TypeError if unhashable.
#     759             pass
#
# KeyboardInterrupt:

# %%
    
    all_d.columns = ['x', 'y','z','dataset',genename ]
    vmin = np.min(all_d[genename])
    vmax = np.max(all_d[genename])
    
    g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = genename,palette= cmap, sharex=False, sharey=False)
    g.map(plt.scatter, 'x', 'y', s=5, lw=1, vmin = vmin, vmax = vmax)

# %%
out = np.load('/Users/work/Documents/GitHub/mlgenomics/datasets/Wang_2018_all_2D_3D_processed.npz')['arr_0']

plot_genes(out[out[:,-1]==0,:],np.array(np.argwhere(all_genes=='Cux2')).flatten(),'Cux2', 'Blues')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b7d19beaf168> in <module>
#       1 out = np.load('/Users/work/Documents/GitHub/mlgenomics/datasets/Wang_2018_all_2D_3D_processed.npz')['arr_0']
#       2
# ----> 3 plot_genes(out[out[:,-1]==0,:],np.array(np.argwhere(all_genes=='Cux2')).flatten(),'Cux2', 'Blues')
#
# <ipython-input-2-8603f7463d87> in plot_genes(data, index, genename, cmap)
#      41
#      42     g = sns.FacetGrid(all_d, col='dataset', margin_titles=True, height=3,  col_wrap=5, hue = genename,palette= cmap, sharex=False, sharey=False)
# ---> 43     g.map(plt.scatter, 'x', 'y', s=5, lw=1, vmin = vmin, vmax = vmax)
#      44
#      45     # Make space for the colorbar
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     721
#     722         # Iterate over the data subsets
# --> 723         for (row_i, col_j, hue_k), data_ijk in self.facet_data():
#     724
#     725             # If this subset is null, move on
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/axisgrid.py in facet_data(self)
#     673                                                     enumerate(col_masks),
#     674                                                     enumerate(hue_masks)):
# --> 675             data_ijk = data[row & col & hue & self._not_na]
#     676             yield (i, j, k), data_ijk
#     677
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other)
#    1827         elif isinstance(other, (ABCSeries, ABCIndexClass)):
#    1828             is_other_int_dtype = is_integer_dtype(other.dtype)
# -> 1829             other = fill_int(other) if is_other_int_dtype else fill_bool(other)
#    1830
#    1831             ovalues = other.values
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops.py in <lambda>(x)
#    1813
#    1814     fill_int = lambda x: x.fillna(0)
# -> 1815     fill_bool = lambda x: x.fillna(False).astype(bool)
#    1816
#    1817     def wrapper(self, other):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
#    5691                                          **kwargs)
# -> 5692             return self._constructor(new_data).__finalize__(self)
#    5693
#    5694         # GH 19920: retain column metadata after concat
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#     267
# --> 268         self.name = name
#     269         self._set_axis(0, index, fastpath=True)
#     270
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5077
#    5078         try:
# -> 5079             object.__getattribute__(self, name)
#    5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in name(self)
#     390         return generic.NDFrame._update_inplace(self, result, **kwargs)
#     391
# --> 392     @property
#     393     def name(self):
#     394         """
#
# KeyboardInterrupt:

# %%
 plot_genes(data,np.array(np.argwhere(all_genes=='Cux2')).flatten(),'Cux2', 'Blues')

# %%
 plot_genes(data,np.array(np.argwhere(all_genes=='Ctgf')).flatten(),'Ctgf', 'Reds')

# %%
 plot_genes(data,np.array(np.argwhere(all_genes=='Enpp2')).flatten(),'Enpp2', 'Greens')

# %%
dirs = os.listdir('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/combinatorially_encoded/all_datasets')


exclude = set(('Astro-1',
 'Astro-2',
 'Endo',
 'Micro',
 'Oligo',
 'PVALB',
 'Reln',
 'SST',
 'Smc',
 'VIP','Astro', 'PV','NPY','Lhx6','nan'))

g, labels = plot_annotations(exclude, 1030,1034)

# %%
exclude = set(( 'eL6-2', 'eL5-3', 'eL4','eL2/3','eL5','el5-1','HPC', 'eL5-2','eL6', 'L5-1', 'eL6-1', 'nan'))

g, labels = plot_annotations(exclude,1030,1034)

# %%
# show cell sampling density 



# how many cells do we have per unit of tissue

# %%
dirs
# Out:
# ['20180505_BY3_1kgenes',
#  '20171110_BF2_dark',
#  '20180410-BY3_1kgenes',
#  '20180421_BZ19_cocaine',
#  '20170915_BD2_dark',
#  '20171115_BF5_light',
#  '20180424_BZ14_control',
#  '20171120_BF4_light',
#  '20180419_BZ9_control',
#  '20180417_BZ5_control']

# %%
ncells=[]
for i in range(len(data)):
    
    ncells.append(data[i].shape[0])

# %%
f = pd.concat([pd.DataFrame(dirs),pd.DataFrame(ncells), pd.DataFrame(region), pd.DataFrame(list(range(0,10))), pd.DataFrame(genenumber),
          pd.DataFrame(dimensions),pd.DataFrame(volume)],axis =1)

# %%
f.columns = ['dataset', 'N cells', 'region', 'dataset ID', 'N genes', 'section dim.', 'cell density']

# %%
f
# Out:
#                  dataset  N cells region  dataset ID N genes  \
# 0   20180505_BY3_1kgenes     1549     vc           0   ~1020
# 1      20171110_BF2_dark     1151     vc           1    ~160
# 2   20180410-BY3_1kgenes      973     vc           2   ~1020
# 3  20180421_BZ19_cocaine     1320   mpfc           3    ~160
# 4      20170915_BD2_dark      941     vc           4    ~160
# 5     20171115_BF5_light      975     vc           5    ~160
# 6  20180424_BZ14_control     1215   mpfc           6    ~160
# 7     20171120_BF4_light      912     vc           7    ~160
# 8   20180419_BZ9_control     1380   mpfc           8    ~160
# 9   20180417_BZ5_control     1127   mpfc           9    ~160
#
#                section dim.         cell density
# 0                        ik                   ik
# 1  [1.4 mm x 0.3 mm x 8 um]  [2740 cells/ 1mm^3]
# 2                        ik                   ik
# 3                   cocaine              cocaine
# 4  [1.4 mm x 0.3 mm x 8 um]  [2740 cells/ 1mm^3]
# 5  [1.4 mm x 0.3 mm x 8 um]  [2740 cells/ 1mm^3]
# 6                   control              control
# 7  [1.4 mm x 0.3 mm x 8 um]  [2740 cells/ 1mm^3]
# 8                   control              control
# 9                   control              control

# %%
# add region

# add number of genes 

region = ['vc', 'vc', 'vc', 'mpfc','vc', 'vc',  'mpfc', 'vc',  'mpfc', 'mpfc']
genenumber = ['~1020', '~160', '~1020', '~160','~160', '~160',  '~160', '~160',  '~160', '~160']

# %%
dimensions = ['ik', ['1.4 mm x 0.3 mm x 8 um'], 'ik',
              'cocaine', ['1.4 mm x 0.3 mm x 8 um'], ['1.4 mm x 0.3 mm x 8 um'], 
              'control', ['1.4 mm x 0.3 mm x 8 um'], 'control', 'control' ]

# %%
ld dimensions
# Out:
# [['1.4 mm x 0.3 mm x 8 um'],
#  ['1.4 mm x 0.3 mm x 8 um'],
#  ['1.4 mm x 0.3 mm x 8 um'],
#  ['1.4 mm x 0.3 mm x 8 um']]

# %%
1151/(0.008*0.3*1.4)
# Out:
# 342559.52380952385

# %%
volume = (0.3*1.4)

# %%
1151/volume
# Out:
# 2740.4761904761904

# %%
volume = ['ik', ['2740 cells/ 1mm^3'], 'ik',
              'cocaine',['2740 cells/ 1mm^3'], ['2740 cells/ 1mm^3'], 
              'control', ['2740 cells/ 1mm^3'], 'control', 'control' ]

# %%
for i in range(len(dirs)):
    print(np.min(np.sum(data[i],axis=1)))
# Out:
# 506.99999999999994
# 167.0
# 334.00000000000006
# 590.0
# 292.99999999999994
# 642.0000000000002
# 176.99999999999997
# 77.0
# 182.0
# 208.99999999999997

# %% [markdown]
# # plotting new 2D data

# %%
out = np.load('/Users/work/Documents/GitHub/mlgenomics/data_preprocessing/Wang_2018_all_2D_3D_processed.npz')['arr_0']
out[out[:,-1]==0,:]
# Out:
# array([[2.70124257e-05, 2.70124257e-05, 2.70124257e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.19019281e-05, 1.19019281e-05, 1.19019281e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.07503763e-05, 1.07503763e-05, 1.07503763e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
 plot_genes(out,np.array(np.argwhere(all_genes=='Ctgf')).flatten(),'Ctgf', 'Reds')

# %%
 plot_genes(out[out[:,-1]!=33,:],np.array(np.argwhere(all_genes=='Ctgf')).flatten(),'Ctgf', 'Reds')

# %%
out[out[:,-1]!=33,:]
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.17679558e-01, 3.86740331e-03, 3.30000000e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         5.93370166e-01, 4.41988950e-03, 3.30000000e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.43093923e-01, 3.31491713e-03, 3.30000000e+01],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         8.33149171e-01, 5.19337017e-02, 3.30000000e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         7.67955801e-01, 5.19337017e-02, 3.30000000e+01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.52486188e-01, 5.19337017e-02, 3.30000000e+01]])

# %%
dirs = os.listdir('/Users/work/Documents/GitHub/mlgenomics/data_as_downloaded/combinatorially_encoded/all_datasets')


exclude = set(('Astro-1',
 'Astro-2',
 'Endo',
 'Micro',
 'Oligo',
 'PVALB',
 'Reln',
 'SST',
 'Smc',
 'VIP','Astro', 'PV','NPY','Lhx6','nan'))

g, labels = plot_annotations(out,exclude, 1030,1034)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-bfd16d89fe49> in <module>
#      13  'VIP','Astro', 'PV','NPY','Lhx6','nan'))
#      14
# ---> 15 g, labels = plot_annotations(out,exclude, 1030,1034)
#
# <ipython-input-54-8603f7463d87> in plot_annotations(data, exclude, start, end)
#      10             new_labels.append([None if item in exclude else item for item in labels])
#      11         else:
# ---> 12             new_data.append(data[i][:,start:end])
#      13             labels = labels.loc[range(data[i].shape[0]),:]
#      14             labels = labels['ClusterName'].to_list()
#
# IndexError: too many indices for array
